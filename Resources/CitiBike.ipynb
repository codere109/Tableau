# %%
import pandas as pd

# %%
cb2019 = pd.read_csv('../Resources/june2019.csv')
cb2020 = pd.read_csv('../Resources/june2020.csv')
cb2021 = pd.read_csv('../Resources/june2021.csv')
cb2022 = pd.read_csv('../Resources/june2022.csv')

# %%
#change gender column values to actual gender name M,F,Unknown for 2019 and 2020 dataset
cb2019.loc[cb2019['gender'] ==0,"gender"]="Unknown"
cb2019.loc[cb2019['gender'] ==1,"gender"]="Male"
cb2019.loc[cb2019['gender'] ==2,"gender"]="Female"

cb2020.loc[cb2020['gender'] ==0,"gender"]="Unknown"
cb2020.loc[cb2020['gender'] ==1,"gender"]="Male"
cb2020.loc[cb2020['gender'] ==2,"gender"]="Female"

# %%
#rename column tripduration for 2019 & 2020
cb2019.rename(columns={"tripduration": "trip-duration(mins)"}, inplace=True)
cb2020.rename(columns={"tripduration": "trip-duration(mins)"}, inplace=True)

# %%
cb2020.isnull().values.any()
# Out:
# False

# %%
cb2021
# Out:
#                 ride_id rideable_type           started_at  \
# 0      8B8A826EA1FB6246   docked_bike  2021-04-02 18:06:51
# 1      6ECB53933BB5424E   docked_bike  2021-04-06 21:19:27
# 2      DC8E726CDD4A3FDE   docked_bike  2021-04-07 17:26:47
# 3      CDBF0A93464AB439   docked_bike  2021-04-30 20:23:42
# 4      7AC523690FC1E82E   docked_bike  2021-04-23 18:48:11
# ...                 ...           ...                  ...
# 23769  BEB399F6639BF799   docked_bike  2021-04-28 20:51:53
# 23770  A4C1021E7C9EE4E3   docked_bike  2021-04-14 06:34:16
# 23771  3EA6DA6311CFDE83   docked_bike  2021-04-09 12:33:19
# 23772  3F0B6BDE42FE6B6E   docked_bike  2021-04-09 08:25:38
# 23773  2E52C2BD921E2C26   docked_bike  2021-04-09 05:49:06
#
#                   ended_at start_station_name start_station_id  \
# 0      2021-04-02 18:42:17        Paulus Hook            JC002
# 1      2021-04-06 21:59:56         Bergen Ave            JC095
# 2      2021-04-07 17:31:01         Bergen Ave            JC095
# ...

# %%
cb2019.to_csv('../Resources/cb2019.csv')

# %%
cb2020.to_csv('../Resources/cb2020.csv')
